# %%
import pandas as pd
import glob
import os

# %%
# path_all='/home/msi/Документы/project/seat_belt/train/RESULTS_OUT/seat_belt_2021-09-03_16-12-42_mobilenet_v3_large/'
path_all='/home/msi/Документы/project/car_classification/RESULT_OUT/cars_classific_2021-09-12_18-34-03_resnet18/'

experiments=glob.glob(f'{path_all}/*')

df_dict={}
df_concat = pd.DataFrame()

for i in experiments:
    df_tmp=pd.read_csv(os.path.join(i,'result.csv'),sep='\t')
    del df_tmp['Unnamed: 0']
    
    
    
    df_param=pd.read_csv(os.path.join(i,'param_expirement.csv'),sep='\t')
    del df_param['Unnamed: 0']
    df_param['hash_exprmnt']=os.path.basename(i)[:8]
    df_param=pd.concat([df_param]*len(df_tmp), ignore_index=True)
    
    df_tmp=pd.concat([df_tmp, df_param], axis=1)
    
    df_dict[os.path.basename(i)[:8]]=df_tmp.copy()
    df_concat = df_concat.append(df_tmp.copy(), ignore_index=True)
    del df_tmp

# %%
df_concat.sort_values(by='valid_loss')
# Out:
#       Epoch  train_loss  train_acc           Name_model  valid_loss  \
# 1316      0       0.050      0.981  checkpoint_0000.pth       0.194
# 356       0       0.046      0.982  checkpoint_0000.pth       0.207
# 259       3       0.027      0.990  checkpoint_0003.pth       0.209
# 210       4       0.090      0.967  checkpoint_0004.pth       0.211
# 1098      2       0.029      0.990  checkpoint_0002.pth       0.216
# ...     ...         ...        ...                  ...         ...
# 815      29       0.157      0.944  checkpoint_0029.pth       2.279
# 806      20       0.160      0.939  checkpoint_0020.pth       2.727
# 811      25       0.148      0.943  checkpoint_0025.pth       3.560
# 455      19       0.082      0.971  checkpoint_0019.pth       4.010
# 277      21       0.379      0.847  checkpoint_0021.pth      34.737
#
#       valid_acc        time  test_loss  test_acc      lr  batch_size  epochs  \
# 1316      0.917  183.834594      0.241     0.885  0.0004        96.0    40.0
# 356       0.921  175.594464      0.382     0.875  0.0023        32.0    30.0
# 259       0.923  174.635200      0.501     0.853  0.0095        32.0   100.0
# 210       0.907  181.083816      0.249     0.863  0.0015        32.0    50.0
# 1098      0.923  174.210557      0.479     0.830  0.0048        32.0   140.0
# ...         ...         ...        ...       ...     ...         ...     ...
# 815       0.691  176.258336        NaN       NaN  0.0089        80.0   120.0
# 806       0.716  178.693366        NaN       NaN  0.0089        80.0   120.0
# 811       0.561  177.328318        NaN       NaN  0.0089        80.0   120.0
# 455       0.711  174.406010        NaN       NaN  0.0077        64.0    90.0
# 277       0.487  166.339786        NaN       NaN  0.0095        32.0   100.0
#
#                 backbone hash_exprmnt
# 1316  mobilenet_v3_large     8ztblc2l
# 356   mobilenet_v3_large     ysnc6uas
# 259   mobilenet_v3_large     2xd5s5di
# 210   mobilenet_v3_large     844q7v8g
# 1098  mobilenet_v3_large     x1butfsm
# ...                  ...          ...
# 815   mobilenet_v3_large     j0b2fada
# 806   mobilenet_v3_large     j0b2fada
# 811   mobilenet_v3_large     j0b2fada
# 455   mobilenet_v3_large     4g6v8d0e
# 277   mobilenet_v3_large     2xd5s5di
#
# [1356 rows x 14 columns]

# %%
df_concat.sort_values(by='valid_loss')
# Out:
#       Epoch  train_loss  train_acc           Name_model  valid_loss  \
# 1316      0       0.050      0.981  checkpoint_0000.pth       0.194
# 356       0       0.046      0.982  checkpoint_0000.pth       0.207
# 259       3       0.027      0.990  checkpoint_0003.pth       0.209
# 210       4       0.090      0.967  checkpoint_0004.pth       0.211
# 1098      2       0.029      0.990  checkpoint_0002.pth       0.216
# ...     ...         ...        ...                  ...         ...
# 815      29       0.157      0.944  checkpoint_0029.pth       2.279
# 806      20       0.160      0.939  checkpoint_0020.pth       2.727
# 811      25       0.148      0.943  checkpoint_0025.pth       3.560
# 455      19       0.082      0.971  checkpoint_0019.pth       4.010
# 277      21       0.379      0.847  checkpoint_0021.pth      34.737
#
#       valid_acc        time  test_loss  test_acc      lr  batch_size  epochs  \
# 1316      0.917  183.834594      0.241     0.885  0.0004        96.0    40.0
# 356       0.921  175.594464      0.382     0.875  0.0023        32.0    30.0
# 259       0.923  174.635200      0.501     0.853  0.0095        32.0   100.0
# 210       0.907  181.083816      0.249     0.863  0.0015        32.0    50.0
# 1098      0.923  174.210557      0.479     0.830  0.0048        32.0   140.0
# ...         ...         ...        ...       ...     ...         ...     ...
# 815       0.691  176.258336        NaN       NaN  0.0089        80.0   120.0
# 806       0.716  178.693366        NaN       NaN  0.0089        80.0   120.0
# 811       0.561  177.328318        NaN       NaN  0.0089        80.0   120.0
# 455       0.711  174.406010        NaN       NaN  0.0077        64.0    90.0
# 277       0.487  166.339786        NaN       NaN  0.0095        32.0   100.0
#
#                 backbone hash_exprmnt
# 1316  mobilenet_v3_large     8ztblc2l
# 356   mobilenet_v3_large     ysnc6uas
# 259   mobilenet_v3_large     2xd5s5di
# 210   mobilenet_v3_large     844q7v8g
# 1098  mobilenet_v3_large     x1butfsm
# ...                  ...          ...
# 815   mobilenet_v3_large     j0b2fada
# 806   mobilenet_v3_large     j0b2fada
# 811   mobilenet_v3_large     j0b2fada
# 455   mobilenet_v3_large     4g6v8d0e
# 277   mobilenet_v3_large     2xd5s5di
#
# [1356 rows x 14 columns]

# %%
df_dict['8ztblc2l']
# Out:
#     Epoch  train_loss  train_acc           Name_model  valid_loss  valid_acc  \
# 0       0       0.050      0.981  checkpoint_0000.pth       0.194      0.917
# 1       1       0.036      0.986  checkpoint_0001.pth       0.224      0.911
# 2       2       0.029      0.989  checkpoint_0002.pth       0.234      0.919
# 3       3       0.026      0.992  checkpoint_0003.pth       0.303      0.900
# 4       4       0.024      0.990  checkpoint_0004.pth       0.270      0.913
# 5       5       0.029      0.989  checkpoint_0005.pth       0.256      0.919
# 6       6       0.031      0.989  checkpoint_0006.pth       0.245      0.928
# 7       7       0.033      0.989  checkpoint_0007.pth       0.264      0.910
# 8       8       0.029      0.991  checkpoint_0008.pth       0.284      0.915
# 9       9       0.031      0.988  checkpoint_0009.pth       0.372      0.912
# 10     10       0.039      0.986  checkpoint_0010.pth       0.411      0.885
# 11     11       0.038      0.987  checkpoint_0011.pth       0.444      0.882
# 12     12       0.031      0.989  checkpoint_0012.pth       0.482      0.888
# 13     13       0.025      0.991  checkpoint_0013.pth       0.299      0.934
# 14     14       0.024      0.992  checkpoint_0014.pth       0.393      0.916
# 15     15       0.021      0.992  checkpoint_0015.pth       0.530      0.871
# 16     16       0.022      0.993  checkpoint_0016.pth       0.246      0.918
# 17     17       0.020      0.992  checkpoint_0017.pth       0.722      0.858
# 18     18       0.017      0.993  checkpoint_0018.pth       0.293      0.918
# 19     19       0.019      0.993  checkpoint_0019.pth       0.330      0.910
# 20     20       0.016      0.995  checkpoint_0020.pth       0.295      0.931
# 21     21       0.008      0.997  checkpoint_0021.pth       0.362      0.923
# 22     22       0.015      0.994  checkpoint_0022.pth       0.701      0.866
# 23     23       0.011      0.996  checkpoint_0023.pth       0.393      0.917
# 24     24       0.007      0.997  checkpoint_0024.pth       0.518      0.898
# 25     25       0.010      0.996  checkpoint_0025.pth       0.434      0.908
# 26     26       0.008      0.997  checkpoint_0026.pth       0.377      0.914
# 27     27       0.010      0.997  checkpoint_0027.pth       0.301      0.930
# 28     28       0.007      0.997  checkpoint_0028.pth       0.326      0.924
# 29     29       0.007      0.998  checkpoint_0029.pth       0.392      0.919
# 30     30       0.005      0.998  checkpoint_0030.pth       0.383      0.920
# 31     31       0.003      0.999  checkpoint_0031.pth       0.355      0.930
# 32     32       0.004      0.998  checkpoint_0032.pth       0.366      0.922
# 33     33       0.004      0.998  checkpoint_0033.pth       0.357      0.930
# 34     34       0.007      0.997  checkpoint_0034.pth       0.355      0.932
# 35     35       0.003      0.999  checkpoint_0035.pth       0.363      0.928
# 36     36       0.004      0.999  checkpoint_0036.pth       0.351      0.931
# 37     37       0.002      0.999  checkpoint_0037.pth       0.348      0.930
# 38     38       0.002      0.999  checkpoint_0038.pth       0.349      0.929
# 39     39       0.004      0.999  checkpoint_0039.pth       0.348      0.929
#
#           time  test_loss  test_acc      lr  batch_size  epochs  \
# 0   183.834594      0.241     0.885  0.0004        96.0    40.0
# 1   184.115855        NaN       NaN  0.0004        96.0    40.0
# 2   187.554614        NaN       NaN  0.0004        96.0    40.0
# 3   185.758894        NaN       NaN  0.0004        96.0    40.0
# 4   193.276582        NaN       NaN  0.0004        96.0    40.0
# 5   183.730150        NaN       NaN  0.0004        96.0    40.0
# 6   185.801547        NaN       NaN  0.0004        96.0    40.0
# 7   186.497292        NaN       NaN  0.0004        96.0    40.0
# 8   195.157229        NaN       NaN  0.0004        96.0    40.0
# 9   190.134779        NaN       NaN  0.0004        96.0    40.0
# 10  191.588802        NaN       NaN  0.0004        96.0    40.0
# 11  185.480290        NaN       NaN  0.0004        96.0    40.0
# 12  188.235772        NaN       NaN  0.0004        96.0    40.0
# 13  194.738667        NaN       NaN  0.0004        96.0    40.0
# 14  200.878447        NaN       NaN  0.0004        96.0    40.0
# 15  193.978614        NaN       NaN  0.0004        96.0    40.0
# 16  192.530406        NaN       NaN  0.0004        96.0    40.0
# 17  190.543245        NaN       NaN  0.0004        96.0    40.0
# 18  183.910632        NaN       NaN  0.0004        96.0    40.0
# 19  185.702263        NaN       NaN  0.0004        96.0    40.0
# 20  184.795795        NaN       NaN  0.0004        96.0    40.0
# 21  192.755307        NaN       NaN  0.0004        96.0    40.0
# 22  189.588934        NaN       NaN  0.0004        96.0    40.0
# 23  185.851755        NaN       NaN  0.0004        96.0    40.0
# 24  189.985457        NaN       NaN  0.0004        96.0    40.0
# 25  183.389941        NaN       NaN  0.0004        96.0    40.0
# 26  187.454853        NaN       NaN  0.0004        96.0    40.0
# 27  182.759662        NaN       NaN  0.0004        96.0    40.0
# 28  189.128849        NaN       NaN  0.0004        96.0    40.0
# 29  193.529865        NaN       NaN  0.0004        96.0    40.0
# 30  188.360494        NaN       NaN  0.0004        96.0    40.0
# 31  182.928552        NaN       NaN  0.0004        96.0    40.0
# 32  184.705624        NaN       NaN  0.0004        96.0    40.0
# 33  184.421694        NaN       NaN  0.0004        96.0    40.0
# 34  196.817444        NaN       NaN  0.0004        96.0    40.0
# 35  184.849608        NaN       NaN  0.0004        96.0    40.0
# 36  194.820197        NaN       NaN  0.0004        96.0    40.0
# 37  187.014683        NaN       NaN  0.0004        96.0    40.0
# 38  189.552881        NaN       NaN  0.0004        96.0    40.0
# 39  176.597614        NaN       NaN  0.0004        96.0    40.0
#
#               backbone hash_exprmnt
# 0   mobilenet_v3_large     8ztblc2l
# 1   mobilenet_v3_large     8ztblc2l
# 2   mobilenet_v3_large     8ztblc2l
# 3   mobilenet_v3_large     8ztblc2l
# 4   mobilenet_v3_large     8ztblc2l
# 5   mobilenet_v3_large     8ztblc2l
# 6   mobilenet_v3_large     8ztblc2l
# 7   mobilenet_v3_large     8ztblc2l
# 8   mobilenet_v3_large     8ztblc2l
# 9   mobilenet_v3_large     8ztblc2l
# 10  mobilenet_v3_large     8ztblc2l
# 11  mobilenet_v3_large     8ztblc2l
# 12  mobilenet_v3_large     8ztblc2l
# 13  mobilenet_v3_large     8ztblc2l
# 14  mobilenet_v3_large     8ztblc2l
# 15  mobilenet_v3_large     8ztblc2l
# 16  mobilenet_v3_large     8ztblc2l
# 17  mobilenet_v3_large     8ztblc2l
# 18  mobilenet_v3_large     8ztblc2l
# 19  mobilenet_v3_large     8ztblc2l
# 20  mobilenet_v3_large     8ztblc2l
# 21  mobilenet_v3_large     8ztblc2l
# 22  mobilenet_v3_large     8ztblc2l
# 23  mobilenet_v3_large     8ztblc2l
# 24  mobilenet_v3_large     8ztblc2l
# 25  mobilenet_v3_large     8ztblc2l
# 26  mobilenet_v3_large     8ztblc2l
# 27  mobilenet_v3_large     8ztblc2l
# 28  mobilenet_v3_large     8ztblc2l
# 29  mobilenet_v3_large     8ztblc2l
# 30  mobilenet_v3_large     8ztblc2l
# 31  mobilenet_v3_large     8ztblc2l
# 32  mobilenet_v3_large     8ztblc2l
# 33  mobilenet_v3_large     8ztblc2l
# 34  mobilenet_v3_large     8ztblc2l
# 35  mobilenet_v3_large     8ztblc2l
# 36  mobilenet_v3_large     8ztblc2l
# 37  mobilenet_v3_large     8ztblc2l
# 38  mobilenet_v3_large     8ztblc2l
# 39  mobilenet_v3_large     8ztblc2l
